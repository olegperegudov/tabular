# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import optuna

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv(r'data/train.csv')
df_test = pd.read_csv(r'data/test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c75c923127c3> in <module>
# ----> 1 df_train = pd.read_csv(r'data/train.csv')
#       2 df_test = pd.read_csv(r'data/test.csv')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train.csv'

# %%
print(f'train na: {df_train.isna().sum().max()}')
print(f'test na: {df_test.isna().sum().max()}')

# %%
df_train.target.value_counts()

# %%
x = df_train.drop(['id', 'target'], 1)
y = df_train.target

ID = df_test.id
df_test.drop('id', 1, inplace=True)

# %%
num_cols = x.select_dtypes(include='number').columns.tolist()
cat_cols = x.select_dtypes(exclude='number').columns.tolist()

# %%
cols = cat_cols + num_cols
df = pd.concat([x[cols], df_test[cols]], 0)
df = pd.get_dummies(df, columns=cat_cols)

# %%
x = df[:len(x)]
test = df[len(x):]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c9cf6523c1e5> in <module>
# ----> 1 x = df[:len(x)]
#       2 test = df[len(x):]
#
# NameError: name 'df' is not defined

# %%
x.shape, test.shape
# Out:
# ((300000, 642), (200000, 642))

# %% [markdown]
# # params

# %%
early_stopping_rounds = 50
n_trials = 30
test_size = 0.1
n_splits = 5 # kfold

# %%
folds = KFold(n_splits=n_splits, shuffle=True, random_state=1)
x_valid_temp = len(next(iter(folds.split(x)))[0])

# %% [markdown]
# # catboost and optuna

# %%
def objective(trial, data=x, target=y):
    x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=test_size, random_state=1)

    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.005, 0.02, 0.05, 0.08, 0.1]),
        'n_estimators': trial.suggest_int('n_estimators', 50, 3000),
        'max_bin': trial.suggest_int('max_bin', 200, 400),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 300),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0.0001, 1.0, log = True),
        'subsample': trial.suggest_float('subsample', 0.1, 0.8),
        'random_seed': 1,
        'task_type': 'GPU',
        'loss_function': 'Logloss',
        'eval_metric': 'AUC',
        'bootstrap_type': 'Poisson'
    }
    
    model = CatBoostClassifier(**params)  
    model.fit(x_train, y_train, eval_set = [(x_valid,y_valid)], early_stopping_rounds=early_stopping_rounds, verbose=False) # was 222
    y_pred = model.predict_proba(x_valid)[:, 1]
    roc_auc = roc_auc_score(y_valid, y_pred)

    return roc_auc

# %%
# %%time
study = optuna.create_study(direction = 'maximize')
study.optimize(objective, n_trials=n_trials) # was 30
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
print('Best value:', study.best_value)
# Out:
# [I 2021-03-25 18:51:50,274] A new study created in memory with name: no-name-bc47e188-54fc-4c1d-bfe6-eee3e01e70cd
# [I 2021-03-25 18:53:08,873] Trial 0 finished with value: 0.8964096325035159 and parameters: {'max_depth': 8, 'learning_rate': 0.1, 'n_estimators': 2475, 'max_bin': 254, 'min_data_in_leaf': 8, 'l2_leaf_reg': 0.03074485903865801, 'subsample': 0.6516535736775653}. Best is trial 0 with value: 0.8964096325035159.
# [I 2021-03-25 18:53:54,472] Trial 1 finished with value: 0.8968586726555974 and parameters: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 1874, 'max_bin': 383, 'min_data_in_leaf': 294, 'l2_leaf_reg': 0.00032811340148320513, 'subsample': 0.47180449406861513}. Best is trial 1 with value: 0.8968586726555974.
# [I 2021-03-25 18:54:00,916] Trial 2 finished with value: 0.8648952973485229 and parameters: {'max_depth': 3, 'learning_rate': 0.005, 'n_estimators': 284, 'max_bin': 261, 'min_data_in_leaf': 148, 'l2_leaf_reg': 0.005613725174259541, 'subsample': 0.14188385769149842}. Best is trial 1 with value: 0.8968586726555974.
# [I 2021-03-25 18:54:35,994] Trial 3 finished with value: 0.8973029231531305 and parameters: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 2662, 'max_bin': 304, 'min_data_in_leaf': 180, 'l2_leaf_reg': 0.017116065550952346, 'subsample': 0.1562692267977145}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:55:12,556] Trial 4 finished with value: 0.887566599429477 and parameters: {'max_depth': 4, 'learning_rate': 0.005, 'n_estimators': 2758, 'max_bin': 395, 'min_data_in_leaf': 21, 'l2_leaf_reg': 0.09335811918447547, 'subsample': 0.7386791825418386}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:55:27,441] Trial 5 finished with value: 0.8958848928651219 and parameters: {'max_depth': 6, 'learning_rate': 0.1, 'n_estimators': 1916, 'max_bin': 370, 'min_data_in_leaf': 117, 'l2_leaf_reg': 0.041986560588808494, 'subsample': 0.22293390107264058}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:55:44,705] Trial 6 finished with value: 0.8945745294224634 and parameters: {'max_depth': 10, 'learning_rate': 0.08, 'n_estimators': 2927, 'max_bin': 242, 'min_data_in_leaf': 245, 'l2_leaf_reg': 0.13535621257172367, 'subsample': 0.11612064378809545}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:56:06,177] Trial 7 finished with value: 0.8942768652985548 and parameters: {'max_depth': 3, 'learning_rate': 0.1, 'n_estimators': 2284, 'max_bin': 329, 'min_data_in_leaf': 81, 'l2_leaf_reg': 0.043754860764017085, 'subsample': 0.16576385675401673}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:56:14,959] Trial 8 finished with value: 0.88455634743491 and parameters: {'max_depth': 4, 'learning_rate': 0.02, 'n_estimators': 467, 'max_bin': 272, 'min_data_in_leaf': 157, 'l2_leaf_reg': 0.18243739011362217, 'subsample': 0.4036756680915885}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:56:47,632] Trial 9 finished with value: 0.8940583021761047 and parameters: {'max_depth': 4, 'learning_rate': 0.02, 'n_estimators': 2427, 'max_bin': 287, 'min_data_in_leaf': 274, 'l2_leaf_reg': 0.08215994672956294, 'subsample': 0.7252320087238685}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:57:05,831] Trial 10 finished with value: 0.8957445072299003 and parameters: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 1084, 'max_bin': 202, 'min_data_in_leaf': 210, 'l2_leaf_reg': 0.0018225178000833137, 'subsample': 0.30620409796351566}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:57:24,278] Trial 11 finished with value: 0.8953894131403203 and parameters: {'max_depth': 8, 'learning_rate': 0.05, 'n_estimators': 1431, 'max_bin': 333, 'min_data_in_leaf': 291, 'l2_leaf_reg': 0.0002515794604701642, 'subsample': 0.5375569250898644}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:57:45,011] Trial 12 finished with value: 0.8945740590611785 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'n_estimators': 1804, 'max_bin': 395, 'min_data_in_leaf': 205, 'l2_leaf_reg': 0.00012268923516721688, 'subsample': 0.49182093662611664}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:58:05,362] Trial 13 finished with value: 0.8943861038389306 and parameters: {'max_depth': 8, 'learning_rate': 0.02, 'n_estimators': 938, 'max_bin': 324, 'min_data_in_leaf': 298, 'l2_leaf_reg': 0.8323947710331756, 'subsample': 0.3533641188147383}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:58:18,987] Trial 14 finished with value: 0.894893640873744 and parameters: {'max_depth': 9, 'learning_rate': 0.08, 'n_estimators': 2015, 'max_bin': 369, 'min_data_in_leaf': 230, 'l2_leaf_reg': 0.0009271044291302182, 'subsample': 0.5787239222769845}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:58:43,512] Trial 15 finished with value: 0.8965150794730458 and parameters: {'max_depth': 7, 'learning_rate': 0.05, 'n_estimators': 2996, 'max_bin': 220, 'min_data_in_leaf': 72, 'l2_leaf_reg': 0.007097852884820853, 'subsample': 0.266097543672443}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:59:05,158] Trial 16 finished with value: 0.89287959400433 and parameters: {'max_depth': 5, 'learning_rate': 0.02, 'n_estimators': 1410, 'max_bin': 360, 'min_data_in_leaf': 174, 'l2_leaf_reg': 0.001660322692323472, 'subsample': 0.4383528610290038}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 18:59:43,573] Trial 17 finished with value: 0.8968500914302032 and parameters: {'max_depth': 7, 'learning_rate': 0.02, 'n_estimators': 2658, 'max_bin': 302, 'min_data_in_leaf': 258, 'l2_leaf_reg': 0.0004860137697516974, 'subsample': 0.6053253832745031}. Best is trial 3 with value: 0.8973029231531305.
# [I 2021-03-25 19:00:20,148] Trial 18 finished with value: 0.8986170437499553 and parameters: {'max_depth': 9, 'learning_rate': 0.05, 'n_estimators': 2152, 'max_bin': 306, 'min_data_in_leaf': 119, 'l2_leaf_reg': 0.5491778959136009, 'subsample': 0.3813342356089708}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:00:52,476] Trial 19 finished with value: 0.896534783021995 and parameters: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 2318, 'max_bin': 302, 'min_data_in_leaf': 124, 'l2_leaf_reg': 0.6856307239591724, 'subsample': 0.21093545494459667}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:01:26,180] Trial 20 finished with value: 0.897818450593675 and parameters: {'max_depth': 9, 'learning_rate': 0.05, 'n_estimators': 2139, 'max_bin': 351, 'min_data_in_leaf': 68, 'l2_leaf_reg': 0.3214479961908313, 'subsample': 0.36216792917585805}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:01:53,207] Trial 21 finished with value: 0.897694441561729 and parameters: {'max_depth': 9, 'learning_rate': 0.05, 'n_estimators': 2144, 'max_bin': 344, 'min_data_in_leaf': 52, 'l2_leaf_reg': 0.39140834710005046, 'subsample': 0.3468283177629221}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:02:26,347] Trial 22 finished with value: 0.8978481235074204 and parameters: {'max_depth': 9, 'learning_rate': 0.05, 'n_estimators': 1637, 'max_bin': 348, 'min_data_in_leaf': 50, 'l2_leaf_reg': 0.33646878233698674, 'subsample': 0.35535425972077955}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:02:55,313] Trial 23 finished with value: 0.8963512159263688 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'n_estimators': 1609, 'max_bin': 347, 'min_data_in_leaf': 46, 'l2_leaf_reg': 0.30464791771257693, 'subsample': 0.38974983101221916}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:03:29,341] Trial 24 finished with value: 0.8976893421570662 and parameters: {'max_depth': 9, 'learning_rate': 0.05, 'n_estimators': 1702, 'max_bin': 319, 'min_data_in_leaf': 97, 'l2_leaf_reg': 0.9415156590634953, 'subsample': 0.30609334466355803}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:03:52,771] Trial 25 finished with value: 0.8974482131651644 and parameters: {'max_depth': 8, 'learning_rate': 0.05, 'n_estimators': 1095, 'max_bin': 351, 'min_data_in_leaf': 40, 'l2_leaf_reg': 0.3511667681668909, 'subsample': 0.42161380824905037}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:04:34,318] Trial 26 finished with value: 0.8979916467965792 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'n_estimators': 2055, 'max_bin': 285, 'min_data_in_leaf': 108, 'l2_leaf_reg': 0.9606140667465336, 'subsample': 0.34838163215975054}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:04:59,882] Trial 27 finished with value: 0.8970324883587303 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'n_estimators': 1304, 'max_bin': 281, 'min_data_in_leaf': 112, 'l2_leaf_reg': 0.7931743899645288, 'subsample': 0.26217158094282716}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:05:27,807] Trial 28 finished with value: 0.8882449407079772 and parameters: {'max_depth': 10, 'learning_rate': 0.005, 'n_estimators': 812, 'max_bin': 312, 'min_data_in_leaf': 139, 'l2_leaf_reg': 0.9784628813966179, 'subsample': 0.5139854867976638}. Best is trial 18 with value: 0.8986170437499553.
# [I 2021-03-25 19:05:49,574] Trial 29 finished with value: 0.8977443686912936 and parameters: {'max_depth': 8, 'learning_rate': 0.08, 'n_estimators': 1604, 'max_bin': 239, 'min_data_in_leaf': 11, 'l2_leaf_reg': 0.19704831983175589, 'subsample': 0.30999412014046296}. Best is trial 18 with value: 0.8986170437499553.
# Number of finished trials: 30
# Best trial: {'max_depth': 9, 'learning_rate': 0.05, 'n_estimators': 2152, 'max_bin': 306, 'min_data_in_leaf': 119, 'l2_leaf_reg': 0.5491778959136009, 'subsample': 0.3813342356089708}
# Best value: 0.8986170437499553
# CPU times: user 17min 18s, sys: 6min 25s, total: 23min 43s
# Wall time: 13min 59s

# %% [markdown]
# # catboost visuals

# %%
# optuna.visualization.plot_optimization_history(study)

# %%
# optuna.visualization.plot_param_importances(study)

# %% [markdown]
# # catboost and best params

# %%
paramsCB = study.best_trial.params
paramsCB['task_type'] = 'GPU'
paramsCB['loss_function'] = 'Logloss'
paramsCB['eval_metric'] = 'AUC'
paramsCB['random_seed'] = 1
paramsCB['bootstrap_type'] = 'Poisson'

# %%
# %%time

folds = KFold(n_splits=n_splits, shuffle=True, random_state=1)

predictions_catb = np.zeros(len(test))
roc_auc_list_catb = []

for fold, (train_idx, valid_idx) in enumerate(folds.split(x, y)):
    
    x_train, y_train = x.iloc[train_idx], y.iloc[train_idx]
    x_valid, y_valid = x.iloc[valid_idx], y.iloc[valid_idx]

    model = CatBoostClassifier(**paramsCB)
   
    model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], verbose=False, early_stopping_rounds=early_stopping_rounds) # was 222
    
    predictions_catb += model.predict_proba(test)[:, 1] / folds.n_splits
    valid_preds_catb = model.predict_proba(x_valid)[:, 1]
    
    roc_auc_list_catb.append(roc_auc_score(y_valid, valid_preds_catb))
    
roc_auc_catb = max(roc_auc_list_catb)
roc_auc_catb
# Out:
# CPU times: user 3min 33s, sys: 1min 17s, total: 4min 50s
# Wall time: 2min 44s

# %%
submission_catb = pd.DataFrame({'id': ID, 'target': predictions_catb})
submission_catb.to_csv('submissionCB.csv', index = False)

# %% [markdown]
# # xgb and optuna

# %%
def objective(trial, data=x, target=y):
    x_train, x_valid, y_train, y_valid=train_test_split(x, y, test_size=test_size, random_state=1)

    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.005, 0.02, 0.05, 0.08, 0.1]),
        'n_estimators': trial.suggest_int('n_estimators', 50, 3000),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
        'gamma': trial.suggest_float('gamma', 0.0001, 1.0, log=True),
        'alpha': trial.suggest_float('alpha', 0.0001, 10.0, log=True),
        'lambda': trial.suggest_float('lambda', 0.0001, 10.0, log=True),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 0.8),
        'subsample': trial.suggest_float('subsample', 0.1, 0.8),
        'tree_method': 'gpu_hist',
        'booster': 'gbtree',
        'random_state': 1,
        'use_label_encoder': False,
        'eval_metric': 'auc'

    }
    
    model = XGBClassifier(**params)  
    model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], early_stopping_rounds=early_stopping_rounds, verbose=False) # was 222
    y_pred = model.predict_proba(x_valid)[:, 1]
    roc_auc = roc_auc_score(y_valid, y_pred)

    return roc_auc

# %%
# %%time
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=n_trials) # was 30
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
print('Best value:', study.best_value)
# Out:
# [I 2021-03-25 19:08:35,496] A new study created in memory with name: no-name-4db4928b-a2bd-4e84-869e-6776a4f9e233
# [I 2021-03-25 19:08:55,256] Trial 0 finished with value: 0.8907465342575941 and parameters: {'max_depth': 4, 'learning_rate': 0.02, 'n_estimators': 766, 'min_child_weight': 148, 'gamma': 0.0006816392257218367, 'alpha': 0.0007736267559768395, 'lambda': 0.03690197077299625, 'colsample_bytree': 0.47784915007063355, 'subsample': 0.7759281600488638}. Best is trial 0 with value: 0.8907465342575941.
# [I 2021-03-25 19:09:11,864] Trial 1 finished with value: 0.897170648382018 and parameters: {'max_depth': 5, 'learning_rate': 0.08, 'n_estimators': 550, 'min_child_weight': 83, 'gamma': 0.041326581682098386, 'alpha': 4.042777701583641, 'lambda': 0.24312217429420901, 'colsample_bytree': 0.5375253726149076, 'subsample': 0.5293556921333198}. Best is trial 1 with value: 0.897170648382018.
# [I 2021-03-25 19:09:39,515] Trial 2 finished with value: 0.8964871187891001 and parameters: {'max_depth': 3, 'learning_rate': 0.08, 'n_estimators': 2622, 'min_child_weight': 218, 'gamma': 0.0017438363286662116, 'alpha': 0.8517060788802917, 'lambda': 0.003933843805776811, 'colsample_bytree': 0.34818654655199505, 'subsample': 0.6409124247125936}. Best is trial 1 with value: 0.897170648382018.
# [I 2021-03-25 19:09:59,817] Trial 3 finished with value: 0.8978175586280677 and parameters: {'max_depth': 7, 'learning_rate': 0.1, 'n_estimators': 2954, 'min_child_weight': 151, 'gamma': 0.2555617650139016, 'alpha': 9.819309829999609, 'lambda': 0.00043050939020353976, 'colsample_bytree': 0.7334632917840122, 'subsample': 0.5045344085728919}. Best is trial 3 with value: 0.8978175586280677.
# [I 2021-03-25 19:10:42,064] Trial 4 finished with value: 0.8959916333281854 and parameters: {'max_depth': 7, 'learning_rate': 0.05, 'n_estimators': 1951, 'min_child_weight': 264, 'gamma': 0.003439195558988805, 'alpha': 0.2726948752643772, 'lambda': 0.5519278964189246, 'colsample_bytree': 0.7945854482007259, 'subsample': 0.3502792531871859}. Best is trial 3 with value: 0.8978175586280677.
# [I 2021-03-25 19:11:11,626] Trial 5 finished with value: 0.8838053209976 and parameters: {'max_depth': 7, 'learning_rate': 0.005, 'n_estimators': 626, 'min_child_weight': 240, 'gamma': 0.0006961296575095539, 'alpha': 0.9413501858253239, 'lambda': 0.00024097593564886502, 'colsample_bytree': 0.6116653490214731, 'subsample': 0.6325010002559402}. Best is trial 3 with value: 0.8978175586280677.
# [I 2021-03-25 19:11:34,815] Trial 6 finished with value: 0.8987580202048394 and parameters: {'max_depth': 6, 'learning_rate': 0.08, 'n_estimators': 2350, 'min_child_weight': 91, 'gamma': 0.0011703747708883393, 'alpha': 0.6342244025781321, 'lambda': 0.0063970337980425816, 'colsample_bytree': 0.5777131145380373, 'subsample': 0.5640721964251447}. Best is trial 6 with value: 0.8987580202048394.
# [I 2021-03-25 19:12:25,604] Trial 7 finished with value: 0.8965330335074595 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'n_estimators': 2876, 'min_child_weight': 264, 'gamma': 0.0018550166480531464, 'alpha': 0.03448644601415214, 'lambda': 0.1429508511540838, 'colsample_bytree': 0.11236721355366663, 'subsample': 0.3991228317217852}. Best is trial 6 with value: 0.8987580202048394.
# [I 2021-03-25 19:12:45,647] Trial 8 finished with value: 0.898349459803831 and parameters: {'max_depth': 9, 'learning_rate': 0.1, 'n_estimators': 1633, 'min_child_weight': 9, 'gamma': 0.01319203431872797, 'alpha': 0.12299455527867689, 'lambda': 1.3917204476497624, 'colsample_bytree': 0.4161752826142675, 'subsample': 0.4464414308552651}. Best is trial 6 with value: 0.8987580202048394.
# [I 2021-03-25 19:13:11,970] Trial 9 finished with value: 0.8964313723726622 and parameters: {'max_depth': 8, 'learning_rate': 0.08, 'n_estimators': 1857, 'min_child_weight': 162, 'gamma': 0.010759069476160406, 'alpha': 0.0005756590463180435, 'lambda': 3.45533744777018, 'colsample_bytree': 0.7464908695902156, 'subsample': 0.2815557008759547}. Best is trial 6 with value: 0.8987580202048394.
# [I 2021-03-25 19:14:04,869] Trial 10 finished with value: 0.892078402388756 and parameters: {'max_depth': 5, 'learning_rate': 0.005, 'n_estimators': 2332, 'min_child_weight': 13, 'gamma': 0.00012664603389194956, 'alpha': 0.004270427636191789, 'lambda': 0.005574172106301313, 'colsample_bytree': 0.16303947451507655, 'subsample': 0.14537829872487312}. Best is trial 6 with value: 0.8987580202048394.
# [I 2021-03-25 19:14:29,992] Trial 11 finished with value: 0.8990306232500409 and parameters: {'max_depth': 10, 'learning_rate': 0.1, 'n_estimators': 1272, 'min_child_weight': 4, 'gamma': 0.021244916430890055, 'alpha': 0.05448471448852201, 'lambda': 6.421438576832842, 'colsample_bytree': 0.3580711814316277, 'subsample': 0.6442083688991095}. Best is trial 11 with value: 0.8990306232500409.
# [I 2021-03-25 19:14:50,978] Trial 12 finished with value: 0.8999669204086068 and parameters: {'max_depth': 10, 'learning_rate': 0.1, 'n_estimators': 1165, 'min_child_weight': 54, 'gamma': 0.09568094272863598, 'alpha': 0.013958526636531656, 'lambda': 0.004244883954295096, 'colsample_bytree': 0.2968227931970461, 'subsample': 0.791520357787775}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:15:12,637] Trial 13 finished with value: 0.8999370868836911 and parameters: {'max_depth': 10, 'learning_rate': 0.1, 'n_estimators': 1139, 'min_child_weight': 55, 'gamma': 0.9407260848820415, 'alpha': 0.007017180007509681, 'lambda': 8.301945516303588, 'colsample_bytree': 0.2717860123686797, 'subsample': 0.7949012404024187}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:15:31,964] Trial 14 finished with value: 0.8995294586010827 and parameters: {'max_depth': 9, 'learning_rate': 0.1, 'n_estimators': 1126, 'min_child_weight': 53, 'gamma': 0.8938778318581907, 'alpha': 0.003569291724517007, 'lambda': 0.0009530049440231674, 'colsample_bytree': 0.24586995804880452, 'subsample': 0.783064825608331}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:15:47,240] Trial 15 finished with value: 0.8993682307984354 and parameters: {'max_depth': 10, 'learning_rate': 0.1, 'n_estimators': 277, 'min_child_weight': 50, 'gamma': 0.17301135177996177, 'alpha': 0.006752568231276178, 'lambda': 0.027638963908797016, 'colsample_bytree': 0.23854345681120454, 'subsample': 0.7911005182193935}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:16:10,666] Trial 16 finished with value: 0.8998169755406855 and parameters: {'max_depth': 9, 'learning_rate': 0.1, 'n_estimators': 1058, 'min_child_weight': 108, 'gamma': 0.8050595757556338, 'alpha': 0.00012111909468413079, 'lambda': 0.03565429374447147, 'colsample_bytree': 0.2609327073876804, 'subsample': 0.7230727683274256}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:16:19,361] Trial 17 finished with value: 0.8859083837401932 and parameters: {'max_depth': 8, 'learning_rate': 0.02, 'n_estimators': 95, 'min_child_weight': 47, 'gamma': 0.1087533006912314, 'alpha': 0.01299414823069005, 'lambda': 0.0020404872398275425, 'colsample_bytree': 0.1623709510153255, 'subsample': 0.6989099301765838}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:16:43,110] Trial 18 finished with value: 0.8945217600487926 and parameters: {'max_depth': 10, 'learning_rate': 0.1, 'n_estimators': 1463, 'min_child_weight': 117, 'gamma': 0.35526566874844684, 'alpha': 0.0006764225676887438, 'lambda': 0.01713185890494487, 'colsample_bytree': 0.3295963478986177, 'subsample': 0.12399246949869586}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:17:09,370] Trial 19 finished with value: 0.8981027323654155 and parameters: {'max_depth': 8, 'learning_rate': 0.1, 'n_estimators': 911, 'min_child_weight': 190, 'gamma': 0.07209778335424817, 'alpha': 0.017839565185145092, 'lambda': 0.12590320266387658, 'colsample_bytree': 0.1019813202395024, 'subsample': 0.717711199255878}. Best is trial 12 with value: 0.8999669204086068.
# [I 2021-03-25 19:18:04,399] Trial 20 finished with value: 0.8999977089963753 and parameters: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 1378, 'min_child_weight': 33, 'gamma': 0.5164231023684138, 'alpha': 0.002286269033367302, 'lambda': 0.00010431617561165493, 'colsample_bytree': 0.4314008847003251, 'subsample': 0.7821582085955274}. Best is trial 20 with value: 0.8999977089963753.
# [I 2021-03-25 19:19:01,961] Trial 21 finished with value: 0.900139339368168 and parameters: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 1461, 'min_child_weight': 32, 'gamma': 0.520530358214376, 'alpha': 0.0017997264178078855, 'lambda': 0.00013629961326197502, 'colsample_bytree': 0.4197378675830371, 'subsample': 0.7921655612018631}. Best is trial 21 with value: 0.900139339368168.
# [I 2021-03-25 19:20:01,799] Trial 22 finished with value: 0.9002002712309669 and parameters: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 1461, 'min_child_weight': 23, 'gamma': 0.43452284181036555, 'alpha': 0.0027194139543546343, 'lambda': 0.00019963861102037959, 'colsample_bytree': 0.4608225512734434, 'subsample': 0.7198173049465847}. Best is trial 22 with value: 0.9002002712309669.
# [I 2021-03-25 19:21:04,993] Trial 23 finished with value: 0.9004018124374032 and parameters: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 1592, 'min_child_weight': 26, 'gamma': 0.4726262590254114, 'alpha': 0.00011459506246923822, 'lambda': 0.00012143852338252219, 'colsample_bytree': 0.4424809950004007, 'subsample': 0.6939674229821571}. Best is trial 23 with value: 0.9004018124374032.
# [I 2021-03-25 19:22:15,379] Trial 24 finished with value: 0.8992761805213574 and parameters: {'max_depth': 8, 'learning_rate': 0.02, 'n_estimators': 1707, 'min_child_weight': 1, 'gamma': 0.4226811688690844, 'alpha': 0.00012515295339492823, 'lambda': 0.00015043690759787356, 'colsample_bytree': 0.49811007431572174, 'subsample': 0.60914003803483}. Best is trial 23 with value: 0.9004018124374032.
# [I 2021-03-25 19:23:29,561] Trial 25 finished with value: 0.9007919627829961 and parameters: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 1924, 'min_child_weight': 21, 'gamma': 0.20774242085473657, 'alpha': 0.0003099308499578175, 'lambda': 0.0007266802253693671, 'colsample_bytree': 0.40545047613575835, 'subsample': 0.7026633887251847}. Best is trial 25 with value: 0.9007919627829961.
# [I 2021-03-25 19:24:41,395] Trial 26 finished with value: 0.8998720106790825 and parameters: {'max_depth': 8, 'learning_rate': 0.02, 'n_estimators': 2113, 'min_child_weight': 85, 'gamma': 0.041738760514006254, 'alpha': 0.0002515643301951545, 'lambda': 0.0005293389010872821, 'colsample_bytree': 0.6472095203078603, 'subsample': 0.698306592937798}. Best is trial 25 with value: 0.9007919627829961.
# [I 2021-03-25 19:25:46,311] Trial 27 finished with value: 0.9003964893243247 and parameters: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 2073, 'min_child_weight': 21, 'gamma': 0.19648040346551007, 'alpha': 0.00027019513584838786, 'lambda': 0.0010177601064255387, 'colsample_bytree': 0.3842782795759276, 'subsample': 0.5862265994480523}. Best is trial 25 with value: 0.9007919627829961.
# [I 2021-03-25 19:26:38,453] Trial 28 finished with value: 0.8990797186431871 and parameters: {'max_depth': 6, 'learning_rate': 0.02, 'n_estimators': 2080, 'min_child_weight': 70, 'gamma': 0.19479462468513858, 'alpha': 0.000259909606304129, 'lambda': 0.0008274135834766439, 'colsample_bytree': 0.38765380736290633, 'subsample': 0.5757142558031646}. Best is trial 25 with value: 0.9007919627829961.
# [I 2021-03-25 19:27:53,401] Trial 29 finished with value: 0.899157640873377 and parameters: {'max_depth': 8, 'learning_rate': 0.02, 'n_estimators': 2352, 'min_child_weight': 121, 'gamma': 0.051064392802291705, 'alpha': 0.0003285921477973851, 'lambda': 0.0016884167750493295, 'colsample_bytree': 0.5061545446315906, 'subsample': 0.4875632287785502}. Best is trial 25 with value: 0.9007919627829961.
# Number of finished trials: 30
# Best trial: {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 1924, 'min_child_weight': 21, 'gamma': 0.20774242085473657, 'alpha': 0.0003099308499578175, 'lambda': 0.0007266802253693671, 'colsample_bytree': 0.40545047613575835, 'subsample': 0.7026633887251847}
# Best value: 0.9007919627829961
# CPU times: user 19min 44s, sys: 39.4 s, total: 20min 24s
# Wall time: 19min 17s

# %%
# optuna.visualization.plot_optimization_history(study)

# %%
# optuna.visualization.plot_param_importances(study)

# %% [markdown]
# # xgb and best params

# %%
paramsXGB = study.best_trial.params
paramsXGB['tree_method'] = 'gpu_hist'
paramsXGB['booster'] = 'gbtree'
paramsXGB['eval_metric'] = 'auc'
paramsXGB['random_state'] = 1
paramsXGB['use_label_encoder'] = False

# %%
# %%time

folds = KFold(n_splits=n_splits, shuffle=True, random_state=1)

predictions_xgb = np.zeros(len(test))
roc_auc_list_xgb = []

for fold, (train_idx, valid_idx) in enumerate(folds.split(x, y)):
    
    x_train, y_train = x.iloc[train_idx], y.iloc[train_idx]
    x_valid, y_valid = x.iloc[valid_idx], y.iloc[valid_idx]

    model = XGBClassifier(**paramsXGB)
   
    model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], eval_metric='auc', verbose=False, early_stopping_rounds=early_stopping_rounds) # was 222
    
    predictions_xgb += model.predict_proba(test)[:, 1] / folds.n_splits
    valid_preds_xgb = model.predict_proba(x_valid)[:, 1]
    
    roc_auc_list_xgb.append(roc_auc_score(y_valid, valid_preds_catb))
    
roc_auc_xgb = max(roc_auc_list_xgb)
roc_auc_xgb
# Out:
# CPU times: user 8min 1s, sys: 10.6 s, total: 8min 12s
# Wall time: 6min 47s

# %%
submission_xgb = pd.DataFrame({'id': ID, 'target': predictions_xgb})
submission_xgb.to_csv('submissionXGB.csv', index = False)

# %% [markdown]
# # lgbm and optuna

# %%
def objective(trial, data=x, target=y):
    x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=test_size, random_state=1)

    params = {
        'reg_alpha': trial.suggest_float('reg_alpha', 0.001, 10.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.001, 10.0),
        'num_leaves': trial.suggest_int('num_leaves', 11, 333),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.02, 0.05, 0.005, 0.1]),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 0.5),
        'n_estimators': trial.suggest_int('n_estimators', 50, 3000),
        'random_state': 1,
        'boosting_type': 'gbdt',
        'metric': 'AUC',
        'device': 'gpu'
    }
    
    model = LGBMClassifier(**params)  
    model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], early_stopping_rounds=early_stopping_rounds, verbose=False) # was 222
    y_pred= model.predict_proba(x_valid)[:, 1]
    roc_auc = roc_auc_score(y_valid, y_pred)

    return roc_auc

# %%
# %%time
study = optuna.create_study(direction = 'maximize')
study.optimize(objective, n_trials=n_trials) # was 30
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
print('Best value:', study.best_value)
# Out:
# [I 2021-03-25 19:34:41,894] A new study created in memory with name: no-name-f07d5e68-97cd-40fc-8c9a-39b1622fb8f1
# [I 2021-03-25 19:35:36,316] Trial 0 finished with value: 0.9003077688609771 and parameters: {'reg_alpha': 3.1742110108843513, 'reg_lambda': 4.956898097285141, 'num_leaves': 215, 'min_child_samples': 69, 'max_depth': 11, 'learning_rate': 0.05, 'colsample_bytree': 0.2795642296872885, 'n_estimators': 2090}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:37:39,091] Trial 1 finished with value: 0.8973236878830275 and parameters: {'reg_alpha': 9.537492668580397, 'reg_lambda': 7.856848730391431, 'num_leaves': 206, 'min_child_samples': 13, 'max_depth': 14, 'learning_rate': 0.005, 'colsample_bytree': 0.1780019474335216, 'n_estimators': 1954}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:38:20,974] Trial 2 finished with value: 0.9000148542388238 and parameters: {'reg_alpha': 6.737406022203017, 'reg_lambda': 6.339944137580976, 'num_leaves': 199, 'min_child_samples': 5, 'max_depth': 15, 'learning_rate': 0.05, 'colsample_bytree': 0.4388329256280906, 'n_estimators': 2301}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:39:07,826] Trial 3 finished with value: 0.8999577053427009 and parameters: {'reg_alpha': 4.3559925174507645, 'reg_lambda': 0.23025585584275754, 'num_leaves': 133, 'min_child_samples': 54, 'max_depth': 16, 'learning_rate': 0.05, 'colsample_bytree': 0.13173014542572747, 'n_estimators': 2745}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:40:11,515] Trial 4 finished with value: 0.899684603255648 and parameters: {'reg_alpha': 9.511613309465213, 'reg_lambda': 3.3222474254115144, 'num_leaves': 120, 'min_child_samples': 98, 'max_depth': 14, 'learning_rate': 0.02, 'colsample_bytree': 0.47564818269508635, 'n_estimators': 1089}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:41:13,058] Trial 5 finished with value: 0.8972386213238083 and parameters: {'reg_alpha': 4.010642640724906, 'reg_lambda': 3.6312480545996655, 'num_leaves': 296, 'min_child_samples': 43, 'max_depth': 5, 'learning_rate': 0.02, 'colsample_bytree': 0.15331758282876184, 'n_estimators': 2192}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:41:32,126] Trial 6 finished with value: 0.8976454666269604 and parameters: {'reg_alpha': 6.843130622839182, 'reg_lambda': 4.940501259590504, 'num_leaves': 293, 'min_child_samples': 67, 'max_depth': 17, 'learning_rate': 0.05, 'colsample_bytree': 0.4468170193878469, 'n_estimators': 171}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:42:10,110] Trial 7 finished with value: 0.8996796931427222 and parameters: {'reg_alpha': 3.3867414983072583, 'reg_lambda': 0.24403915266873155, 'num_leaves': 271, 'min_child_samples': 63, 'max_depth': 11, 'learning_rate': 0.05, 'colsample_bytree': 0.4514684758477908, 'n_estimators': 2745}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:42:34,136] Trial 8 finished with value: 0.8930450292460321 and parameters: {'reg_alpha': 3.179509118577348, 'reg_lambda': 8.637534765099304, 'num_leaves': 325, 'min_child_samples': 37, 'max_depth': 6, 'learning_rate': 0.02, 'colsample_bytree': 0.4889393657853678, 'n_estimators': 522}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:42:58,992] Trial 9 finished with value: 0.89503845478838 and parameters: {'reg_alpha': 0.9037027933593224, 'reg_lambda': 4.450875261074227, 'num_leaves': 286, 'min_child_samples': 96, 'max_depth': 19, 'learning_rate': 0.02, 'colsample_bytree': 0.12408290575088313, 'n_estimators': 295}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:43:52,100] Trial 10 finished with value: 0.8962722296471748 and parameters: {'reg_alpha': 0.5736684699026933, 'reg_lambda': 2.2853636199250675, 'num_leaves': 34, 'min_child_samples': 80, 'max_depth': 10, 'learning_rate': 0.01, 'colsample_bytree': 0.3030565316460197, 'n_estimators': 1361}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:44:20,927] Trial 11 finished with value: 0.8994500306411697 and parameters: {'reg_alpha': 7.1307436441743075, 'reg_lambda': 6.747403612906265, 'num_leaves': 203, 'min_child_samples': 8, 'max_depth': 9, 'learning_rate': 0.1, 'colsample_bytree': 0.32338645951682676, 'n_estimators': 2025}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:45:05,157] Trial 12 finished with value: 0.8999529156881527 and parameters: {'reg_alpha': 6.300733972572759, 'reg_lambda': 6.230315249302251, 'num_leaves': 225, 'min_child_samples': 25, 'max_depth': 8, 'learning_rate': 0.05, 'colsample_bytree': 0.37305430441509574, 'n_estimators': 2411}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:45:42,054] Trial 13 finished with value: 0.9000018676784681 and parameters: {'reg_alpha': 5.70913738175363, 'reg_lambda': 9.9144279824231, 'num_leaves': 153, 'min_child_samples': 83, 'max_depth': 13, 'learning_rate': 0.05, 'colsample_bytree': 0.2257700008564812, 'n_estimators': 1623}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:46:07,057] Trial 14 finished with value: 0.8999310324161753 and parameters: {'reg_alpha': 2.195553760840922, 'reg_lambda': 6.064910540731738, 'num_leaves': 86, 'min_child_samples': 78, 'max_depth': 20, 'learning_rate': 0.1, 'colsample_bytree': 0.24089607005568558, 'n_estimators': 2501}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:46:47,886] Trial 15 finished with value: 0.8997792548600768 and parameters: {'reg_alpha': 8.024202886996152, 'reg_lambda': 2.146265762248658, 'num_leaves': 239, 'min_child_samples': 25, 'max_depth': 16, 'learning_rate': 0.05, 'colsample_bytree': 0.3845670696736753, 'n_estimators': 1713}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:49:33,869] Trial 16 finished with value: 0.898981063231723 and parameters: {'reg_alpha': 2.0914652495106147, 'reg_lambda': 7.600522522844381, 'num_leaves': 172, 'min_child_samples': 66, 'max_depth': 12, 'learning_rate': 0.005, 'colsample_bytree': 0.3709285311335604, 'n_estimators': 2963}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:51:12,301] Trial 17 finished with value: 0.8997995721731419 and parameters: {'reg_alpha': 5.161487352114741, 'reg_lambda': 5.67985742942758, 'num_leaves': 249, 'min_child_samples': 52, 'max_depth': 18, 'learning_rate': 0.01, 'colsample_bytree': 0.2447819466119941, 'n_estimators': 1320}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:51:48,200] Trial 18 finished with value: 0.8991936149075067 and parameters: {'reg_alpha': 8.096779866038396, 'reg_lambda': 9.736172104893956, 'num_leaves': 188, 'min_child_samples': 89, 'max_depth': 7, 'learning_rate': 0.05, 'colsample_bytree': 0.3395804647311107, 'n_estimators': 917}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:52:30,531] Trial 19 finished with value: 0.9002873482978737 and parameters: {'reg_alpha': 2.405954397366109, 'reg_lambda': 7.1945337589295795, 'num_leaves': 72, 'min_child_samples': 34, 'max_depth': 15, 'learning_rate': 0.05, 'colsample_bytree': 0.2725355714885004, 'n_estimators': 2348}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:53:05,093] Trial 20 finished with value: 0.9000626417981532 and parameters: {'reg_alpha': 1.784727104481489, 'reg_lambda': 8.481670059248497, 'num_leaves': 28, 'min_child_samples': 35, 'max_depth': 12, 'learning_rate': 0.1, 'colsample_bytree': 0.2596154929962356, 'n_estimators': 1937}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:53:41,670] Trial 21 finished with value: 0.8993180254673789 and parameters: {'reg_alpha': 1.6083273037788122, 'reg_lambda': 8.87903704067976, 'num_leaves': 15, 'min_child_samples': 32, 'max_depth': 12, 'learning_rate': 0.1, 'colsample_bytree': 0.2720384174974529, 'n_estimators': 1848}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:54:09,055] Trial 22 finished with value: 0.8996804044207626 and parameters: {'reg_alpha': 2.8022997124675184, 'reg_lambda': 7.353799134538483, 'num_leaves': 56, 'min_child_samples': 43, 'max_depth': 10, 'learning_rate': 0.1, 'colsample_bytree': 0.19536431007756716, 'n_estimators': 2640}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:54:34,094] Trial 23 finished with value: 0.8993191554816856 and parameters: {'reg_alpha': 1.384349588466033, 'reg_lambda': 8.874144979560706, 'num_leaves': 84, 'min_child_samples': 19, 'max_depth': 13, 'learning_rate': 0.1, 'colsample_bytree': 0.27577597607920334, 'n_estimators': 2134}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:55:37,234] Trial 24 finished with value: 0.9000593033802526 and parameters: {'reg_alpha': 0.1463464134431458, 'reg_lambda': 5.2870719415006695, 'num_leaves': 20, 'min_child_samples': 57, 'max_depth': 11, 'learning_rate': 0.05, 'colsample_bytree': 0.2721419018400416, 'n_estimators': 2981}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:57:07,117] Trial 25 finished with value: 0.8967603728831535 and parameters: {'reg_alpha': 4.030078889161007, 'reg_lambda': 8.140729365917027, 'num_leaves': 78, 'min_child_samples': 45, 'max_depth': 14, 'learning_rate': 0.005, 'colsample_bytree': 0.2086215901561221, 'n_estimators': 1844}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:57:28,713] Trial 26 finished with value: 0.8998562621802061 and parameters: {'reg_alpha': 2.5803651241127854, 'reg_lambda': 7.089909643488406, 'num_leaves': 111, 'min_child_samples': 33, 'max_depth': 11, 'learning_rate': 0.1, 'colsample_bytree': 0.307198940119905, 'n_estimators': 1509}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:59:07,167] Trial 27 finished with value: 0.8990876803683521 and parameters: {'reg_alpha': 1.5530661444610827, 'reg_lambda': 4.705490681283578, 'num_leaves': 47, 'min_child_samples': 73, 'max_depth': 15, 'learning_rate': 0.01, 'colsample_bytree': 0.35134998510537147, 'n_estimators': 2420}. Best is trial 0 with value: 0.9003077688609771.
# [I 2021-03-25 19:59:52,492] Trial 28 finished with value: 0.900353560252902 and parameters: {'reg_alpha': 3.513934835282675, 'reg_lambda': 3.7744569735669833, 'num_leaves': 155, 'min_child_samples': 48, 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.2706264252200076, 'n_estimators': 2216}. Best is trial 28 with value: 0.900353560252902.
# [I 2021-03-25 20:00:41,230] Trial 29 finished with value: 0.9002774879192291 and parameters: {'reg_alpha': 4.69531060049856, 'reg_lambda': 3.855602417277832, 'num_leaves': 156, 'min_child_samples': 48, 'max_depth': 8, 'learning_rate': 0.05, 'colsample_bytree': 0.18207221701477583, 'n_estimators': 2225}. Best is trial 28 with value: 0.900353560252902.
# Number of finished trials: 30
# Best trial: {'reg_alpha': 3.513934835282675, 'reg_lambda': 3.7744569735669833, 'num_leaves': 155, 'min_child_samples': 48, 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.2706264252200076, 'n_estimators': 2216}
# Best value: 0.900353560252902
# CPU times: user 47min 23s, sys: 1min 1s, total: 48min 25s
# Wall time: 25min 59s

# %% [markdown]
# # lgbm visuals

# %%
# optuna.visualization.plot_optimization_history(study)

# %%
# optuna.visualization.plot_param_importances(study)

# %% [markdown]
# # lgbm and best params

# %%
paramsLGBM = study.best_trial.params
paramsLGBM['boosting_type'] = 'gbdt'
paramsLGBM['metric'] = 'AUC'
paramsLGBM['random_state'] = 1

# %%
# %%time

folds = KFold(n_splits=n_splits, shuffle=True, random_state=1)

predictions_lgbm = np.zeros(len(test))
roc_auc_list_lgbm = []

for fold, (train_idx, valid_idx) in enumerate(folds.split(x, y)):
    
    x_train, y_train = x.iloc[train_idx], y.iloc[train_idx]
    x_valid, y_valid = x.iloc[valid_idx], y.iloc[valid_idx]

    model = LGBMClassifier(**paramsLGBM)
   
    model.fit(x_train, y_train, eval_set = [(x_valid, y_valid)], eval_metric='auc', verbose=False, early_stopping_rounds=early_stopping_rounds) # was 222
    
    predictions_lgbm += model.predict_proba(test)[:, 1] / folds.n_splits
    valid_preds_lgbm = model.predict_proba(x_valid)[:, 1]
    
    roc_auc_list_lgbm.append(roc_auc_score(y_valid, valid_preds_catb))
    
roc_auc_lgbm = max(roc_auc_list_lgbm)
roc_auc_lgbm
# Out:
# CPU times: user 11min 51s, sys: 8.38 s, total: 12min
# Wall time: 6min 25s

# %%
submission_lgbm = pd.DataFrame({'id': ID, 'target': predictions_lgbm})
submission_lgbm.to_csv('submissionLGBM.csv', index = False)

# %% [markdown]
# # results

# %%
print(f'roc auc catboost: {roc_auc_catb}')
print(f'roc auc xgb: {roc_auc_xgb}')
print(f'roc auc lgbm: {roc_auc_lgbm}')
# Out:
# roc auc catboost: 0.8942327916650583
# roc auc xgb: 0.8915750866233396
# roc auc lgbm: 0.8915750866233396

# %% [markdown]
# # final submission

# %%
final = pd.DataFrame({'id':ID, 'catboost': predictions_catb, 'xgb': predictions_xgb, 'lgbm': predictions_lgbm})
final.head()

# %%
final['target'] = final.loc[:, ['catboost', 'xgb', 'lgbm']].mean(axis=1)
final.drop(['catboost', 'xgb', 'lgbm'], 1, inplace=True)

# %%
final.head()
# Out:
#    id    target
# 0   5  0.131032
# 1   6  0.406565
# 2   8  0.015783
# 3   9  0.213555
# 4  11  0.115598

# %%
final.to_csv('submission.csv', index=False)
